# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True) #load_dotenv is an utility function that looks for a file with a particular name in your root directory. 
# In our case, the file is .env. It assumes that this is where you have the variables that you want to use for this project. 
# override=True means that if you already have a variable in your environment, it will override it.
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI() #you can name it specifically such as openai_python_client, but we just call it openai to make it simple.
# This code deos not do anything with the OpenAI API yet. It's a light-weight client library that connects to the openAI end points in the cloud.

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", 
            "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 equals 4.

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# If it takes 5 machines 5 minutes to make 5 widgets, how long would it take 100 machines to make 100 widgets?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# Let's analyze the problem step-by-step:
#
# - 5 machines take 5 minutes to make 5 widgets.
#
# This means:
#
# - In 5 minutes, 5 machines produce 5 widgets.
# - Therefore, 1 machine produces 1 widget in 5 minutes.
#
# Now, if 1 machine makes 1 widget in 5 minutes, then:
#
# - How long would it take 100 machines to make 100 widgets?
#
# Since each machine produces 1 widget in 5 minutes, 100 machines will produce 100 widgets in the same 5 minutes.
#
# **Answer: 5 minutes.**

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Let's analyze the problem step-by-step:
#
# - 5 machines take 5 minutes to make 5 widgets.
#
# This means:
#
# - In 5 minutes, 5 machines produce 5 widgets.
# - Therefore, 1 machine produces 1 widget in 5 minutes.
#
# Now, if 1 machine makes 1 widget in 5 minutes, then:
#
# - How long would it take 100 machines to make 100 widgets?
#
# Since each machine produces 1 widget in 5 minutes, 100 machines will produce 100 widgets in the same 5 minutes.
#
# **Answer: 5 minutes.**

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "Pick a business area that might be worth exploring for an Agentic AI opportunity."}]

# Then make the first call:

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

# Then read the business idea:

business_idea = response.choices[0].message.content

# And repeat! In the next message, include the business idea within the message

# %%
print(business_idea)
# Out:
# One promising business area for exploring an Agentic AI opportunity is **personalized healthcare management**.
#
# ### Why personalized healthcare management?
#
# 1. **Complex Decision-Making**: Managing health involves interpreting diverse data sets—medical history, genetics, lifestyle, symptoms, and ongoing treatments. An agentic AI can autonomously gather, analyze, and synthesize this information to provide personalized health recommendations or alerts.
#
# 2. **Continuous Monitoring and Adaptation**: Agentic AI systems could actively monitor real-time data from wearables, lab reports, and patient feedback, adapting care plans dynamically and even prompting medical consultation when necessary.
#
# 3. **Patient Empowerment and Engagement**: By acting as an autonomous health assistant, an agentic AI can help patients follow treatment plans, manage medication schedules, and adopt lifestyle changes through personalized coaching and motivation.
#
# 4. **Integration Across Stakeholders**: The AI can serve as a bridge between patients, healthcare providers, and insurers to streamline communications, optimize care pathways, and reduce costs from mismanagement or hospital readmissions.
#
# ### Potential applications
#
# - Autonomous chronic disease management (e.g., diabetes, heart disease)
# - Personalized preventive care and risk assessments
# - Mental health support through adaptive interventions
# - Automated scheduling and coordination of care services
#
# ### Summary
#
# Agentic AI in personalized healthcare management has the potential to improve patient outcomes, reduce healthcare costs, and elevate the quality of care by continuously and proactively managing complex, individualized health needs. This makes it a highly valuable business area for exploration.

# %%
messages = [{"role": "user", 
            "content": f"Based on the {business_idea} above, what are the top three pain points in the industry that are best solved by the Agentic AI?"}]

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

pain_points = response.choices[0].message.content

print(pain_points)

messages = [{"role": "user", 
            "content": f"What are the most promising and unique Agentic AI solutions for the {pain_points}?"}]

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

solutions = response.choices[0].message.content

print(solutions)
# Out:
# The top three pain points in personalized healthcare management that are best solved by Agentic AI are:
#
# 1. **Complexity in Data Integration and Decision-Making**
#    Managing health requires synthesizing vast and diverse data sources—medical records, genetic information, lifestyle inputs, real-time wearable data, and more. Currently, this complexity overwhelms both patients and providers, leading to suboptimal or delayed decisions. An agentic AI can autonomously gather, analyze, and interpret this heterogeneous data to deliver timely, personalized health insights and recommendations, overcoming human limitations in processing complexity.
#
# 2. **Lack of Continuous Monitoring and Adaptive Care**
#    Many healthcare systems rely on episodic visits and static care plans, which do not account for patients’ dynamic health changes. This gap results in missed early warnings and reactive rather than proactive interventions. Agentic AI can continuously monitor real-time data streams, adapt care plans on the fly, alert patients and providers to emerging risks, and prompt timely interventions, significantly improving disease management and prevention.
#
# 3. **Poor Patient Engagement and Medication Adherence**
#    Patients often struggle to follow complex treatment regimens, manage medications, and sustain lifestyle changes due to lack of personalized support. This leads to poor health outcomes and increased costs due to complications or hospitalizations. An agentic AI acting as an autonomous health assistant can empower and engage patients through tailored coaching, reminders, and motivational interventions, improving adherence and overall health outcomes.
#
# Together, these pain points highlight critical challenges in personalized healthcare that agentic AI is uniquely positioned to address through autonomous, adaptive, and continuous management.
# Certainly! Agentic AI—AI systems capable of autonomous decision-making, proactive interventions, and continuous adaptation—are uniquely suited to tackle key challenges in personalized healthcare management. Below are some of the most promising and unique agentic AI solutions designed to address the top three pain points you identified:
#
# ---
#
# ### 1. Complexity in Data Integration and Decision-Making
#
# **Pain Point:** Healthcare data is extremely heterogeneous (EHRs, genomics, wearables, lifestyle, social determinants) and complex, overwhelming both patients and providers.
#
# **Promising Agentic AI Solutions:**
#
# - **Autonomous Multi-Modal Data Fusion Agents**
#   AI systems that independently gather and integrate diverse data types—from structured EHRs, unstructured clinical notes, genomics, and continuous wearables—and interpret them contextually. Using deep representation learning and causal inference, these agents can synthesize insights without clinician input, delivering holistic, personalized diagnostics and prognostic predictions.
#
# - **Explainable Clinical Decision Support Agents**
#   Agentic AI that not only autonomously analyzes combined patient data but also explains reasoning and risk factors transparently to both doctors and patients. This transparency overcomes trust barriers and aids complex clinical decision-making by presenting actionable insights with confidence scores, and alternative treatment pathways.
#
# - **Proactive Risk Stratification and Alerting Systems**
#   Autonomous agents monitor integrated patient profiles and predict worsening conditions (e.g., diabetes complications, heart failure exacerbations) before symptoms arise, with minimal human oversight, enabling early preemptive care.
#
# ---
#
# ### 2. Lack of Continuous Monitoring and Adaptive Care
#
# **Pain Point:** Episodic care plans don’t reflect patients’ dynamic physiologies or changing lifestyle.
#
# **Promising Agentic AI Solutions:**
#
# - **Continuous Autonomous Health Agents**
#   AI agents continuously analyze streaming biometric and behavioral data (via wearables, IoT devices, smartphone sensors) to detect subtle deteriorations or improvements, adjusting care plans and medication dosages autonomously and recommending interventions in real-time.
#
# - **Adaptive Careplan Optimization Engines**
#   Based on real-time feedback and outcomes, these agents dynamically tailor treatment regimens and rehabilitation steps, learning from individual responses and compliance patterns to optimize efficacy without waiting for clinician input.
#
# - **Closed-Loop AI-Enabled Home Monitoring Systems**
#   These systems autonomously monitor multiple health parameters (e.g., glucose, blood pressure, oxygen saturation) and engage smart devices (e.g., insulin pumps, CPAP machines) to adjust therapy dynamically, drastically reducing latency between symptom onset and therapeutic response.
#
# ---
#
# ### 3. Poor Patient Engagement and Medication Adherence
#
# **Pain Point:** Complex regimens and insufficient motivation lead to poor adherence and engagement.
#
# **Promising Agentic AI Solutions:**
#
# - **Autonomous Personal Health Coaches**
#   Conversational AI agents use natural language understanding and personalized behavioral nudges informed by psychological models (e.g., motivational interviewing, habit formation) to deliver tailored coaching, reminders, and encouragement continuously, improving adherence and lifestyle changes.
#
# - **Emotionally Intelligent Virtual Companions**
#   Agents capable of interpreting emotional state (via voice, text sentiment, or facial recognition) to adapt motivational strategies, provide empathetic support, and escalate to human providers if needed, fostering sustained engagement.
#
# - **Gamified Adherence and Progress Tracking Agents**
#   AI that autonomously creates personalized challenges, rewards, and social connectivity based on patient preferences and goals, transforming medication and lifestyle adherence into engaging, rewarding experiences.
#
# ---
#
# ### Why Agentic AI is Unique for These Solutions:
#
# - **Autonomy:** Operates independently, reducing burden on providers and patients by proactively managing care.
# - **Adaptivity:** Continuously learns and adjusts based on incoming data and user feedback.
# - **Context-Awareness:** Understands individual patient context holistically (clinical + behavioral + environmental).
# - **Scalability:** Can manage vast patient populations with highly personalized protocols without proportional resource increases.
# - **Trust and Explainability:** Provides transparent rationale behind autonomous decisions, critical for healthcare adoption.
#
# ---
#
# ### Leading Examples / Startups / Research Directions
#
# - **Ada Health and Buoy Health:** AI symptom checkers evolving toward agentic triage and decision making.
# - **HealthLoop (now part of Well Health):** Remote patient engagement with intelligent automated follow-ups.
# - **CloudMedX:** Integrates complex data for predictive risk scoring autonomously.
# - **Pear Therapeutics:** AI-enabled digital therapeutics with adaptive behavioral coaching.
# - **Research on Reinforcement Learning (RL) for Dynamic Treatment Regimes:** Agentic RL optimizing medication dosing and timing on a personalized, continuous basis.
# - **OpenAI / DeepMind Work in Clinical AI:** Applying large language models with agentic control to integrate clinical knowledge for active patient management.
#
# ---
#
# ### Summary:
#
# Agentic AI promises to revolutionize personalized healthcare by autonomously integrating complex data, continuously monitoring patients, adapting care dynamically, and engaging patients with personalized support. These capabilities uniquely address the top barriers limiting effective chronic disease management and preventive care.
#
# If you want, I can provide deeper technical architectures, implementation challenges, or key ethical considerations related to agentic AI deployment in healthcare!
